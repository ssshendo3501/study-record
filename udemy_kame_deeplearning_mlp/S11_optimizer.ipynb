# %% [markdown]
# # Optimizer

# %% [markdown]
# ## スクラッチ実装

# %%
import torch
import numpy as np
from torch import nn
from torch.nn import functional as F
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# ================MLP自作クラス=================
class MLP(nn.Module):
    def __init__(self, num_in, num_hidden, num_out):
        super().__init__()  # 親クラスであるnn.Moduleのインスタンス変数を呼ぶ
        self.l1 = nn.Linear(in_features=num_in, out_features=num_hidden)  # 隠れ層のLinear層
        self.l2 = nn.Linear(in_features=num_hidden, out_features=num_out)  # 出力層のLinear層
        # モデルにはReLUも必要だが、ReLUはパラメータを持たない関数なので、F.functionで定義する

    # 順伝播の関数
    def forward(self, x):  
        x = self.l2(F.relu(self.l1(x)))
        return x

# モデルの初期化
num_in = 64
num_hidden = 30
num_out = 10
model = MLP(num_in, num_hidden, num_out)

# model.parametes()はGeneratorなのでlistで返せるようにしておく
model.parameters()
# Out:
# <generator object Module.parameters at 0x7f99c0249ba0>

# %%
# ================Optimizer自作クラス=================
class Optimizer():

    def __init__(self, parameters, lr=0.03):
        self.parameters = list(parameters)
        self.lr = lr

    def step(self):
        with torch.no_grad():
            for param in self.parameters:
                param -= self.lr * param.grad

    def zero_grad(self):
        for param in self.parameters:
            if param.grad is not None:
                param.grad.zero_()

# %%
learning_rate = 0.01
opt = Optimizer(parameters=model.parameters(), lr=learning_rate)

# %%
## Refactoring後の学習ループ(OptimizerやDataset, Dataloaderは後ほどRefactoring)
# ===データの準備====
dataset = datasets.load_digits()
data = dataset['data']
target = dataset['target']
images = dataset['images']
X_train, X_val, y_train, y_val = train_test_split(images, target, test_size=0.2, random_state=42)
X_train = (X_train - X_train.mean()) / X_train.std()
X_val = (X_val - X_train.mean()) / X_train.std()
X_train = torch.tensor(X_train.reshape(-1, 64), dtype=torch.float32)
X_val = torch.tensor(X_val.reshape(-1, 64), dtype=torch.float32)
y_train = torch.tensor(y_train)
y_val =torch.tensor(y_val)
batch_size = 30
num_batches = np.ceil(len(y_train)/batch_size).astype(int)

# ログ
train_losses = []
val_losses = []
val_accuracies = []
for epoch in range(100):
    # エポック毎にデータをシャッフル
    shuffled_indices = np.random.permutation(len(y_train))
    
    running_loss = 0.0
    
    for i in range(num_batches):
        
        # mini batch作成
        start = i * batch_size
        end = start + batch_size

        batch_indices = shuffled_indices[start:end]
        y = y_train[batch_indices] # batch_size x 10
        
        X = X_train[batch_indices] # batch_size x 64
        # 順伝播と逆伝播の計算
        preds = model.forward(X) 
        loss = F.cross_entropy(preds, y)
        loss.backward()
        running_loss += loss.item()

        # パラメータ更新  # ============ここの部分をOptimzerクラスに書き換える============
        # with torch.no_grad():
        #     for param in model.parameters(): 
        #         param -= learning_rate * param.grad

        # model.zero_grad()
        opt.step()
        opt.zero_grad()

    # validation
    with torch.no_grad():
        preds_val = model(X_val)  
        val_loss = F.cross_entropy(preds_val, y_val)
        val_accuracy = torch.sum(torch.argmax(preds_val, dim=-1) == y_val) / y_val.shape[0] 

    train_losses.append(running_loss/num_batches)
    val_losses.append(val_loss.item())
    val_accuracies.append(val_accuracy)
    print(f'epoch: {epoch}: train error: {running_loss/num_batches}, validation error: {val_loss.item()}, validation accuracy: {val_accuracy}')
# Out:
# epoch: 0: train error: 2.2959280759096146, validation error: 2.3013250827789307, validation accuracy: 0.19166666269302368
# epoch: 1: train error: 2.185075889031092, validation error: 1.8151521682739258, validation accuracy: 0.3194444477558136
# epoch: 2: train error: 2.0629258677363396, validation error: 1.4268486499786377, validation accuracy: 0.46388888359069824
# epoch: 3: train error: 1.9155480787158012, validation error: 1.1287775039672852, validation accuracy: 0.6027777791023254
# epoch: 4: train error: 1.74362313747406, validation error: 0.9431319236755371, validation accuracy: 0.6472222208976746
# epoch: 5: train error: 1.564373475809892, validation error: 0.8413791060447693, validation accuracy: 0.6694444417953491
# epoch: 6: train error: 1.3898871317505836, validation error: 0.7255154848098755, validation accuracy: 0.7416666746139526
# epoch: 7: train error: 1.2285650844375293, validation error: 0.6491394639015198, validation accuracy: 0.7888888716697693
# epoch: 8: train error: 1.082624978075425, validation error: 0.5706552267074585, validation accuracy: 0.8361111283302307
# epoch: 9: train error: 0.9545779141287009, validation error: 0.5424240827560425, validation accuracy: 0.8611111044883728
# epoch: 10: train error: 0.8420158525307974, validation error: 0.5041573643684387, validation accuracy: 0.8777777552604675
# epoch: 11: train error: 0.7476194190482298, validation error: 0.5194311141967773, validation accuracy: 0.8861111402511597
# epoch: 12: train error: 0.6679573779304823, validation error: 0.47514501214027405, validation accuracy: 0.8999999761581421
# epoch: 13: train error: 0.6017115786671638, validation error: 0.4812885820865631, validation accuracy: 0.9055555462837219
# epoch: 14: train error: 0.5454751520107189, validation error: 0.4811423420906067, validation accuracy: 0.9027777910232544
# epoch: 15: train error: 0.49880738991002244, validation error: 0.5060757994651794, validation accuracy: 0.9111111164093018
# epoch: 16: train error: 0.4598306075980266, validation error: 0.4809572994709015, validation accuracy: 0.9111111164093018
# epoch: 17: train error: 0.4259850389013688, validation error: 0.4798511564731598, validation accuracy: 0.9111111164093018
# epoch: 18: train error: 0.3979621243973573, validation error: 0.454450786113739, validation accuracy: 0.9138888716697693
# epoch: 19: train error: 0.3723264994720618, validation error: 0.44808709621429443, validation accuracy: 0.9166666865348816
# epoch: 20: train error: 0.35011286567896605, validation error: 0.43770429491996765, validation accuracy: 0.9166666865348816
# epoch: 21: train error: 0.33155318442732096, validation error: 0.44540929794311523, validation accuracy: 0.9194444417953491
# epoch: 22: train error: 0.3141577827433745, validation error: 0.43210211396217346, validation accuracy: 0.9166666865348816
# epoch: 23: train error: 0.299672307446599, validation error: 0.41823524236679077, validation accuracy: 0.9166666865348816
# epoch: 24: train error: 0.2860890117784341, validation error: 0.443570077419281, validation accuracy: 0.9222221970558167
# epoch: 25: train error: 0.2735892276590069, validation error: 0.41791075468063354, validation accuracy: 0.9222221970558167
# epoch: 26: train error: 0.2624380177197357, validation error: 0.4197992980480194, validation accuracy: 0.9194444417953491
# epoch: 27: train error: 0.2531791532722612, validation error: 0.40826696157455444, validation accuracy: 0.9222221970558167
# epoch: 28: train error: 0.24368330712119737, validation error: 0.4160177409648895, validation accuracy: 0.9222221970558167
# epoch: 29: train error: 0.23574659414589405, validation error: 0.39777204394340515, validation accuracy: 0.9222221970558167
# epoch: 30: train error: 0.22759645090748867, validation error: 0.41690242290496826, validation accuracy: 0.9194444417953491
# epoch: 31: train error: 0.22095063887536526, validation error: 0.39462071657180786, validation accuracy: 0.925000011920929
# epoch: 32: train error: 0.21495718276128173, validation error: 0.40719592571258545, validation accuracy: 0.925000011920929
# epoch: 33: train error: 0.2079746963766714, validation error: 0.402570515871048, validation accuracy: 0.9222221970558167
# epoch: 34: train error: 0.20240414701402187, validation error: 0.4437801241874695, validation accuracy: 0.925000011920929
# epoch: 35: train error: 0.19728054401154319, validation error: 0.4311976432800293, validation accuracy: 0.925000011920929
# epoch: 36: train error: 0.1919028670527041, validation error: 0.39031803607940674, validation accuracy: 0.925000011920929
# epoch: 37: train error: 0.18775682539368668, validation error: 0.43205881118774414, validation accuracy: 0.9277777671813965
# epoch: 38: train error: 0.18331184657290578, validation error: 0.3950784504413605, validation accuracy: 0.9277777671813965
# epoch: 39: train error: 0.17901563070093593, validation error: 0.38863301277160645, validation accuracy: 0.9277777671813965
# epoch: 40: train error: 0.1749471997221311, validation error: 0.3789174258708954, validation accuracy: 0.9305555820465088
# epoch: 41: train error: 0.17143088610221943, validation error: 0.41688159108161926, validation accuracy: 0.9277777671813965
# epoch: 42: train error: 0.16770709197347364, validation error: 0.42095401883125305, validation accuracy: 0.9277777671813965
# epoch: 43: train error: 0.16483890001351634, validation error: 0.41647857427597046, validation accuracy: 0.9277777671813965
# epoch: 44: train error: 0.1612131599492083, validation error: 0.434011846780777, validation accuracy: 0.9305555820465088
# epoch: 45: train error: 0.15814577415585518, validation error: 0.41515520215034485, validation accuracy: 0.9305555820465088
# epoch: 46: train error: 0.15517624358957013, validation error: 0.4017993211746216, validation accuracy: 0.9333333373069763
# epoch: 47: train error: 0.15277843192840615, validation error: 0.432163268327713, validation accuracy: 0.9333333373069763
# epoch: 48: train error: 0.15024340362288058, validation error: 0.4211564362049103, validation accuracy: 0.9305555820465088
# epoch: 49: train error: 0.14728545832137266, validation error: 0.4440408945083618, validation accuracy: 0.9305555820465088
# epoch: 50: train error: 0.14485968106115857, validation error: 0.4295676648616791, validation accuracy: 0.9333333373069763
# epoch: 51: train error: 0.14290198505235216, validation error: 0.4097222089767456, validation accuracy: 0.9333333373069763
# epoch: 52: train error: 0.1402739620922754, validation error: 0.39466267824172974, validation accuracy: 0.9361110925674438
# epoch: 53: train error: 0.13841367520702383, validation error: 0.422693133354187, validation accuracy: 0.9361110925674438
# epoch: 54: train error: 0.13626541344759366, validation error: 0.4472498595714569, validation accuracy: 0.9388889074325562
# epoch: 55: train error: 0.13464732025749981, validation error: 0.4175181984901428, validation accuracy: 0.9361110925674438
# epoch: 56: train error: 0.13200294055665532, validation error: 0.46170613169670105, validation accuracy: 0.9388889074325562
# epoch: 57: train error: 0.1303514246828854, validation error: 0.42647773027420044, validation accuracy: 0.9388889074325562
# epoch: 58: train error: 0.1285752026208987, validation error: 0.43837594985961914, validation accuracy: 0.9388889074325562
# epoch: 59: train error: 0.12678443749124804, validation error: 0.45278090238571167, validation accuracy: 0.9388889074325562
# epoch: 60: train error: 0.12517503066919744, validation error: 0.4460407793521881, validation accuracy: 0.9388889074325562
# epoch: 61: train error: 0.12359170080162585, validation error: 0.43896833062171936, validation accuracy: 0.9388889074325562
# epoch: 62: train error: 0.12241672514937818, validation error: 0.4421057105064392, validation accuracy: 0.9388889074325562
# epoch: 63: train error: 0.12067554611712694, validation error: 0.446400910615921, validation accuracy: 0.9388889074325562
# epoch: 64: train error: 0.11912418575957417, validation error: 0.44640010595321655, validation accuracy: 0.9388889074325562
# epoch: 65: train error: 0.11729640055758257, validation error: 0.47321537137031555, validation accuracy: 0.9388889074325562
# epoch: 66: train error: 0.11600198643282056, validation error: 0.47258076071739197, validation accuracy: 0.9361110925674438
# epoch: 67: train error: 0.11475943805028994, validation error: 0.44620341062545776, validation accuracy: 0.9388889074325562
# epoch: 68: train error: 0.11353558596844475, validation error: 0.4718887209892273, validation accuracy: 0.9416666626930237
# epoch: 69: train error: 0.1120253795137008, validation error: 0.4528654217720032, validation accuracy: 0.9361110925674438
# epoch: 70: train error: 0.11080031399615109, validation error: 0.46664369106292725, validation accuracy: 0.9388889074325562
# epoch: 71: train error: 0.10999570166071256, validation error: 0.4388156533241272, validation accuracy: 0.9388889074325562
# epoch: 72: train error: 0.1083033907537659, validation error: 0.4644630551338196, validation accuracy: 0.9361110925674438
# epoch: 73: train error: 0.10717901110183448, validation error: 0.47322142124176025, validation accuracy: 0.9361110925674438
# epoch: 74: train error: 0.10599584241087238, validation error: 0.48137542605400085, validation accuracy: 0.9333333373069763
# epoch: 75: train error: 0.10492904992618908, validation error: 0.4556307792663574, validation accuracy: 0.9333333373069763
# epoch: 76: train error: 0.10379648798455794, validation error: 0.4551744759082794, validation accuracy: 0.9388889074325562
# epoch: 77: train error: 0.10266077689205606, validation error: 0.46604716777801514, validation accuracy: 0.9388889074325562
# epoch: 78: train error: 0.10162704115888725, validation error: 0.46517324447631836, validation accuracy: 0.9388889074325562
# epoch: 79: train error: 0.10051420823826145, validation error: 0.49861016869544983, validation accuracy: 0.9361110925674438
# epoch: 80: train error: 0.09955565778849025, validation error: 0.4826030433177948, validation accuracy: 0.9333333373069763
# epoch: 81: train error: 0.09869862043221171, validation error: 0.49687886238098145, validation accuracy: 0.9333333373069763
# epoch: 82: train error: 0.09750774681257705, validation error: 0.5106172561645508, validation accuracy: 0.9305555820465088
# epoch: 83: train error: 0.09633468731772155, validation error: 0.5085907578468323, validation accuracy: 0.9361110925674438
# epoch: 84: train error: 0.09557971858885139, validation error: 0.48071005940437317, validation accuracy: 0.9361110925674438
# epoch: 85: train error: 0.0945967214841706, validation error: 0.4829980134963989, validation accuracy: 0.9361110925674438
# epoch: 86: train error: 0.0937395488532881, validation error: 0.5106620788574219, validation accuracy: 0.9333333373069763
# epoch: 87: train error: 0.09285017002063493, validation error: 0.5253344774246216, validation accuracy: 0.9333333373069763
# epoch: 88: train error: 0.09205284035609414, validation error: 0.5246853232383728, validation accuracy: 0.9361110925674438
# epoch: 89: train error: 0.09150830730019759, validation error: 0.4931619465351105, validation accuracy: 0.9361110925674438
# epoch: 90: train error: 0.09055567152487735, validation error: 0.49265533685684204, validation accuracy: 0.9361110925674438
# epoch: 91: train error: 0.08940630200474213, validation error: 0.5298417210578918, validation accuracy: 0.9361110925674438
# epoch: 92: train error: 0.0889384695328772, validation error: 0.4896039664745331, validation accuracy: 0.9361110925674438
# epoch: 93: train error: 0.08792847363899152, validation error: 0.5144345760345459, validation accuracy: 0.9361110925674438
# epoch: 94: train error: 0.08742927874360855, validation error: 0.5062912106513977, validation accuracy: 0.9361110925674438
# epoch: 95: train error: 0.08634667211056997, validation error: 0.5021739602088928, validation accuracy: 0.9333333373069763
# epoch: 96: train error: 0.08580357069149613, validation error: 0.48862630128860474, validation accuracy: 0.9333333373069763
# epoch: 97: train error: 0.08509936730843037, validation error: 0.5161667466163635, validation accuracy: 0.9361110925674438
# epoch: 98: train error: 0.08427965804003179, validation error: 0.5467738509178162, validation accuracy: 0.9361110925674438
# epoch: 99: train error: 0.08353800245095044, validation error: 0.5421239733695984, validation accuracy: 0.9361110925674438

# %% [markdown]
# ## torch.optim

# %%
from torch import optim
opt = optim.SGD(model.parameters(), lr=learning_rate)

# %%
## Refactoring後の学習ループ(OptimizerやDataset, Dataloaderは後ほどRefactoring)
# ===データの準備====
dataset = datasets.load_digits()
data = dataset['data']
target = dataset['target']
images = dataset['images']
X_train, X_val, y_train, y_val = train_test_split(images, target, test_size=0.2, random_state=42)
X_train = (X_train - X_train.mean()) / X_train.std()
X_val = (X_val - X_train.mean()) / X_train.std()
X_train = torch.tensor(X_train.reshape(-1, 64), dtype=torch.float32)
X_val = torch.tensor(X_val.reshape(-1, 64), dtype=torch.float32)
y_train = torch.tensor(y_train)
y_val =torch.tensor(y_val)
batch_size = 30
num_batches = np.ceil(len(y_train)/batch_size).astype(int)



# ログ
train_losses = []
val_losses = []
val_accuracies = []
for epoch in range(100):
    # エポック毎にデータをシャッフル
    shuffled_indices = np.random.permutation(len(y_train))
    
    running_loss = 0.0
    
    for i in range(num_batches):
        
        # mini batch作成
        start = i * batch_size
        end = start + batch_size

        batch_indices = shuffled_indices[start:end]
        y = y_train[batch_indices] # batch_size x 10
        
        X = X_train[batch_indices] # batch_size x 64
        # 順伝播と逆伝播の計算
        preds = model.forward(X) 
        loss = F.cross_entropy(preds, y)
        loss.backward()
        running_loss += loss.item()

        # パラメータ更新  # ============ここの部分をOptimzerクラスに書き換える============
        # with torch.no_grad():
        #     for param in model.parameters(): 
        #         param -= learning_rate * param.grad

        # model.zero_grad()
        opt.step()
        opt.zero_grad()

    # validation
    with torch.no_grad():
        preds_val = model(X_val)  
        val_loss = F.cross_entropy(preds_val, y_val)
        val_accuracy = torch.sum(torch.argmax(preds_val, dim=-1) == y_val) / y_val.shape[0] 

    train_losses.append(running_loss/num_batches)
    val_losses.append(val_loss.item())
    val_accuracies.append(val_accuracy)
    print(f'epoch: {epoch}: train error: {running_loss/num_batches}, validation error: {val_loss.item()}, validation accuracy: {val_accuracy}')
# Out:
# epoch: 0: train error: 0.08290219120681286, validation error: 0.522064745426178, validation accuracy: 0.9361110925674438
# epoch: 1: train error: 0.08210546263338377, validation error: 0.5342123508453369, validation accuracy: 0.9361110925674438
# epoch: 2: train error: 0.08127990520248811, validation error: 0.5317471027374268, validation accuracy: 0.9361110925674438
# epoch: 3: train error: 0.08050674840342253, validation error: 0.5266197323799133, validation accuracy: 0.9361110925674438
# epoch: 4: train error: 0.07995347950297098, validation error: 0.5186716914176941, validation accuracy: 0.9361110925674438
# epoch: 5: train error: 0.07918641312668721, validation error: 0.5206379294395447, validation accuracy: 0.9388889074325562
# epoch: 6: train error: 0.07863732206169516, validation error: 0.5513700842857361, validation accuracy: 0.9361110925674438
# epoch: 7: train error: 0.07801462104544044, validation error: 0.5447068810462952, validation accuracy: 0.9388889074325562
# epoch: 8: train error: 0.07730703804797183, validation error: 0.5553762912750244, validation accuracy: 0.9388889074325562
# epoch: 9: train error: 0.07660181762184948, validation error: 0.5495067834854126, validation accuracy: 0.9361110925674438
# epoch: 10: train error: 0.07606964942533523, validation error: 0.5676013827323914, validation accuracy: 0.9388889074325562
# epoch: 11: train error: 0.07539777892331283, validation error: 0.5576460361480713, validation accuracy: 0.9416666626930237
# epoch: 12: train error: 0.07488151069264859, validation error: 0.5818741917610168, validation accuracy: 0.9416666626930237
# epoch: 13: train error: 0.07447257222762953, validation error: 0.556750476360321, validation accuracy: 0.9416666626930237
# epoch: 14: train error: 0.07376966128746669, validation error: 0.5657593607902527, validation accuracy: 0.9416666626930237
# epoch: 15: train error: 0.07337025822683547, validation error: 0.5508262515068054, validation accuracy: 0.9416666626930237
# epoch: 16: train error: 0.07280189086062212, validation error: 0.5585541725158691, validation accuracy: 0.9416666626930237
# epoch: 17: train error: 0.07214507805959632, validation error: 0.5649490356445312, validation accuracy: 0.9416666626930237
# epoch: 18: train error: 0.07156529312487692, validation error: 0.5698428750038147, validation accuracy: 0.9416666626930237
# epoch: 19: train error: 0.07096543376489232, validation error: 0.5994018316268921, validation accuracy: 0.9416666626930237
# epoch: 20: train error: 0.07078745014344652, validation error: 0.5659378170967102, validation accuracy: 0.9416666626930237
# epoch: 21: train error: 0.0698528273884828, validation error: 0.590545654296875, validation accuracy: 0.9444444179534912
# epoch: 22: train error: 0.06941119274900605, validation error: 0.6023437976837158, validation accuracy: 0.9416666626930237
# epoch: 23: train error: 0.06900524514882515, validation error: 0.6023133993148804, validation accuracy: 0.9416666626930237
# epoch: 24: train error: 0.06841154509068777, validation error: 0.5695191621780396, validation accuracy: 0.9416666626930237
# epoch: 25: train error: 0.06780568448205788, validation error: 0.585140585899353, validation accuracy: 0.9416666626930237
# epoch: 26: train error: 0.06750461938402925, validation error: 0.5918709635734558, validation accuracy: 0.9416666626930237
# epoch: 27: train error: 0.0672343394641454, validation error: 0.5820179581642151, validation accuracy: 0.9416666626930237
# epoch: 28: train error: 0.0664505618236338, validation error: 0.5785484910011292, validation accuracy: 0.9444444179534912
# epoch: 29: train error: 0.06594084723231693, validation error: 0.6003373861312866, validation accuracy: 0.9416666626930237
# epoch: 30: train error: 0.06544645559430744, validation error: 0.6167804002761841, validation accuracy: 0.9416666626930237
# epoch: 31: train error: 0.06508674464809398, validation error: 0.6028121709823608, validation accuracy: 0.9416666626930237
# epoch: 32: train error: 0.06448111091352378, validation error: 0.6006709933280945, validation accuracy: 0.9416666626930237
# epoch: 33: train error: 0.06403167223713051, validation error: 0.596378743648529, validation accuracy: 0.9444444179534912
# epoch: 34: train error: 0.06367665577757482, validation error: 0.610528290271759, validation accuracy: 0.9416666626930237
# epoch: 35: train error: 0.0631798113269421, validation error: 0.606281578540802, validation accuracy: 0.9444444179534912
# epoch: 36: train error: 0.06276156111077096, validation error: 0.6197934746742249, validation accuracy: 0.9416666626930237
# epoch: 37: train error: 0.062491373217199, validation error: 0.6197390556335449, validation accuracy: 0.9416666626930237
# epoch: 38: train error: 0.06205038584691162, validation error: 0.5965675115585327, validation accuracy: 0.9444444179534912
# epoch: 39: train error: 0.061606823078667126, validation error: 0.6285551190376282, validation accuracy: 0.9444444179534912
# epoch: 40: train error: 0.06103133635285, validation error: 0.6177873015403748, validation accuracy: 0.9444444179534912
# epoch: 41: train error: 0.06066575658041984, validation error: 0.6357590556144714, validation accuracy: 0.9416666626930237
# epoch: 42: train error: 0.06012992805335671, validation error: 0.6613966226577759, validation accuracy: 0.9388889074325562
# epoch: 43: train error: 0.06017878308193758, validation error: 0.6412084698677063, validation accuracy: 0.9416666626930237
# epoch: 44: train error: 0.05934004980372265, validation error: 0.6393879652023315, validation accuracy: 0.9416666626930237
# epoch: 45: train error: 0.05910107272211462, validation error: 0.63791823387146, validation accuracy: 0.9444444179534912
# epoch: 46: train error: 0.05889807738518963, validation error: 0.6462211608886719, validation accuracy: 0.9416666626930237
# epoch: 47: train error: 0.05831047193108437, validation error: 0.6600087285041809, validation accuracy: 0.9416666626930237
# epoch: 48: train error: 0.058000339777208865, validation error: 0.6618720293045044, validation accuracy: 0.9416666626930237
# epoch: 49: train error: 0.05785390210803598, validation error: 0.655394434928894, validation accuracy: 0.9416666626930237
# epoch: 50: train error: 0.05722924195773279, validation error: 0.6347587704658508, validation accuracy: 0.9444444179534912
# epoch: 51: train error: 0.05677044077310711, validation error: 0.6509644389152527, validation accuracy: 0.9444444179534912
# epoch: 52: train error: 0.05653498960115636, validation error: 0.6621134281158447, validation accuracy: 0.9416666626930237
# epoch: 53: train error: 0.056034175116413586, validation error: 0.6499917507171631, validation accuracy: 0.9472222328186035
# epoch: 54: train error: 0.05576635218070199, validation error: 0.6629993915557861, validation accuracy: 0.9472222328186035
# epoch: 55: train error: 0.05548804457066581, validation error: 0.6700621843338013, validation accuracy: 0.9416666626930237
# epoch: 56: train error: 0.05534395592985675, validation error: 0.6676977276802063, validation accuracy: 0.9416666626930237
# epoch: 57: train error: 0.05478297309794774, validation error: 0.6553865075111389, validation accuracy: 0.9472222328186035
# epoch: 58: train error: 0.0543806609348394, validation error: 0.6668926477432251, validation accuracy: 0.9444444179534912
# epoch: 59: train error: 0.05421014842189228, validation error: 0.6620977520942688, validation accuracy: 0.9444444179534912
# epoch: 60: train error: 0.05375671656414246, validation error: 0.6599743962287903, validation accuracy: 0.9444444179534912
# epoch: 61: train error: 0.053487143789728485, validation error: 0.6809031367301941, validation accuracy: 0.9416666626930237
# epoch: 62: train error: 0.053031079606929175, validation error: 0.6876987218856812, validation accuracy: 0.9416666626930237
# epoch: 63: train error: 0.052520655716458954, validation error: 0.6553634405136108, validation accuracy: 0.9472222328186035
# epoch: 64: train error: 0.052392810001038015, validation error: 0.7060993313789368, validation accuracy: 0.9416666626930237
# epoch: 65: train error: 0.052180726740819715, validation error: 0.6911240220069885, validation accuracy: 0.9444444179534912
# epoch: 66: train error: 0.051991295690337815, validation error: 0.6915053725242615, validation accuracy: 0.9444444179534912
# epoch: 67: train error: 0.051566235488280654, validation error: 0.7052517533302307, validation accuracy: 0.9444444179534912
# epoch: 68: train error: 0.05121416307520121, validation error: 0.687896192073822, validation accuracy: 0.9444444179534912
# epoch: 69: train error: 0.050780483366300665, validation error: 0.6935593485832214, validation accuracy: 0.9444444179534912
# epoch: 70: train error: 0.050794787549724184, validation error: 0.6908361911773682, validation accuracy: 0.9444444179534912
# epoch: 71: train error: 0.05017332827749973, validation error: 0.7001379132270813, validation accuracy: 0.9444444179534912
# epoch: 72: train error: 0.04994837722430626, validation error: 0.6895542740821838, validation accuracy: 0.9444444179534912
# epoch: 73: train error: 0.04971056509142121, validation error: 0.7094846367835999, validation accuracy: 0.9444444179534912
# epoch: 74: train error: 0.04948954724629099, validation error: 0.713727593421936, validation accuracy: 0.9416666626930237
# epoch: 75: train error: 0.049163816341509424, validation error: 0.7221329808235168, validation accuracy: 0.9444444179534912
# epoch: 76: train error: 0.04888013664943477, validation error: 0.7075181603431702, validation accuracy: 0.9444444179534912
# epoch: 77: train error: 0.048807996965479106, validation error: 0.7358392477035522, validation accuracy: 0.9388889074325562
# epoch: 78: train error: 0.04820638862050449, validation error: 0.7373470664024353, validation accuracy: 0.9388889074325562
# epoch: 79: train error: 0.048251178940214835, validation error: 0.7190963625907898, validation accuracy: 0.9444444179534912
# epoch: 80: train error: 0.04776987402389447, validation error: 0.7220767736434937, validation accuracy: 0.9416666626930237
# epoch: 81: train error: 0.04741028069596117, validation error: 0.7259674668312073, validation accuracy: 0.9416666626930237
# epoch: 82: train error: 0.04743074361855785, validation error: 0.7247812747955322, validation accuracy: 0.9388889074325562
# epoch: 83: train error: 0.0471355989187335, validation error: 0.7270443439483643, validation accuracy: 0.9388889074325562
# epoch: 84: train error: 0.046641105494927615, validation error: 0.7284510135650635, validation accuracy: 0.9388889074325562
# epoch: 85: train error: 0.046548668236937374, validation error: 0.7196974754333496, validation accuracy: 0.9444444179534912
# epoch: 86: train error: 0.046201968672297276, validation error: 0.7265942692756653, validation accuracy: 0.9388889074325562
# epoch: 87: train error: 0.04585917889683818, validation error: 0.7441869378089905, validation accuracy: 0.9388889074325562
# epoch: 88: train error: 0.045624490439270936, validation error: 0.723690390586853, validation accuracy: 0.9472222328186035
# epoch: 89: train error: 0.04545381366430471, validation error: 0.7420966029167175, validation accuracy: 0.9416666626930237
# epoch: 90: train error: 0.045153304507645466, validation error: 0.7428293228149414, validation accuracy: 0.9388889074325562
# epoch: 91: train error: 0.044943597982637584, validation error: 0.7444465756416321, validation accuracy: 0.9416666626930237
# epoch: 92: train error: 0.04457740404177457, validation error: 0.7539564371109009, validation accuracy: 0.9388889074325562
# epoch: 93: train error: 0.04443440211859221, validation error: 0.7382959127426147, validation accuracy: 0.9416666626930237
# epoch: 94: train error: 0.044091135961934924, validation error: 0.7431612014770508, validation accuracy: 0.9416666626930237
# epoch: 95: train error: 0.044332535015807174, validation error: 0.7504708170890808, validation accuracy: 0.9416666626930237
# epoch: 96: train error: 0.04371621554795032, validation error: 0.756732702255249, validation accuracy: 0.9416666626930237
# epoch: 97: train error: 0.04334825500457858, validation error: 0.7760477662086487, validation accuracy: 0.9416666626930237
# epoch: 98: train error: 0.04319312200338269, validation error: 0.7683767676353455, validation accuracy: 0.9416666626930237
# epoch: 99: train error: 0.04285422068399688, validation error: 0.781740665435791, validation accuracy: 0.9416666626930237
